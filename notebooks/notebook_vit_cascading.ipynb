# %% [markdown]
# # ViT-B/16 Cascading Randomization
#
# ViT sanity checks with Captum + attention maps.

# %%
import os
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd()
if not (PROJECT_ROOT / "src").exists():
    PROJECT_ROOT = PROJECT_ROOT.parent
sys.path.insert(0, str(PROJECT_ROOT / "src"))

from experiment_utils import run_vit_pipeline

# ============ CONFIG ============
IMAGENET_ROOT = Path(os.environ.get("IMAGENET_ROOT", "/path/to/imagenet"))
RESULTS_DIR = PROJECT_ROOT / "results" / "vit"
NUM_IMAGES = 500
IMAGE_SIZE = 224
BATCH_SIZE = 8
DEVICE = "cuda" if __import__("torch").cuda.is_available() else "cpu"
IG_STEPS = 50
SKIP_QUAL = False
# ================================

run_vit_pipeline(
    imagenet_root=IMAGENET_ROOT,
    results_dir=RESULTS_DIR,
    model_name="vit_base_patch16_224",
    grid_size=14,
    num_images=NUM_IMAGES,
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    device=DEVICE,
    ig_steps=IG_STEPS,
    skip_qual=SKIP_QUAL,
)
print("Finished:", RESULTS_DIR)
